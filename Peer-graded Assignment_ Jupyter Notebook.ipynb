# %% [markdown]
# # My Jupyter NoteBook On IBM Watson Studio

# %% [markdown]
# #### Polin Tsenova
# Data Solutions Executive

# %% [markdown]
# ##### I am interested in Data Science because I love to gain insigths from data

# %% [markdown]
# ### The foolowing is test code of Gauss Formula

# %%
def gauss(n):
    return (n * (n + 1)) / 2
gauss(100) == sum(range(101))
# Out:
# True

# %% [markdown]
# [Jupyter Planet Intersting Video](https://www.youtube.com/watch?v=PtkqwslbLY8)

# %% [markdown]
# ### Table
#
# |ID|Product|Quantity|
# |--|-------|--------|
# |1|Cheese|10|
# |2|Eggs|25|
# |3|Bread|3|
# |4|Milk|2|

# %% [markdown]
# # Course Cariculum
# 1. What is Data Science?
# 2. Tools for Data Science
# 3. Data Science Methodology
# 4. Python for Data Science
